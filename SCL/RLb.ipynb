# %% [markdown]
# # Install package

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi

# %%
# !pip install mat4py
from google.colab import drive
drive.mount('/content/drive')
from scipy.io import loadmat
from scipy.io import savemat
import os
os.chdir('/content/drive/My Drive')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mat4py in /usr/local/lib/python3.8/dist-packages (0.5.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import collections
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import gym
import tensorflow as tf
import os
import random
from tensorflow.keras import models, layers, optimizers
from tensorflow.keras.layers import RNN
import tensorflow.keras.backend as K
import sys
from gym import spaces
from gym.utils import seeding
import copy
from mat4py import loadmat
from tensorflow.keras import layers
from tensorflow import keras
import time
np.set_printoptions(precision=16)

# %% [markdown]
# # Environment Setup

# %%
# Transient Frequency Control Porblem Environment
class Transient_Frequency(gym.Env):
    def  __init__(self,M,E,Pm,D,D_reactance,delta_t,omega_max,omega_min,dim_omega,dim_lambda,Penalty_action):
        self.param_gamma=1
        self.M=M
        self.E=E
        self.Pm=Pm
        self.D=D
        self.D_reactance=D_reactance
        self.delta_t=delta_t
        self.omega_max=omega_max
        self.omega_min=omega_min
        self.dim_omega=dim_omega
        self.dim_lambda=dim_lambda
        self.Penalty_action=Penalty_action
        self.viewer = None
        self.state=[]

        self.state_transfer1=np.vstack((np.hstack((np.identity((dim_lambda)),np.zeros((dim_lambda,dim_omega)))),\
          np.hstack((delta_t*np.transpose(D),np.identity((dim_omega))-delta_t*np.diag(np.squeeze(E/M))))))

        self.state_transfer2=np.hstack((np.zeros((dim_omega,dim_lambda)),np.identity((dim_omega))))

        self.state_transfer3=np.hstack((np.zeros((dim_omega,dim_lambda)),delta_t*(np.diag(np.squeeze((M**(-1)))))))

        self.select_add_omega=np.vstack((np.zeros((dim_lambda,1)),np.ones((dim_omega,1))))

        self.select_omega=np.vstack((np.zeros((dim_lambda,dim_omega)),np.identity(dim_omega)))

        self.select_lambda=np.vstack((np.identity(dim_lambda),np.zeros((dim_omega,dim_lambda))))

    def step(self,action,Pm):
        self.state=copy.deepcopy(self.state@self.state_transfer1 \
                -((delta_t*((np.sin(self.state@self.select_lambda))@D_reactance)@D)*(M**(-1)))@self.state_transfer2 \
                    + (Pm+action)@self.state_transfer3)

        loss = self.param_gamma*pow(self.state,2)@self.select_add_omega
        return self.state, loss

    def set_state(self, state_input):
        self.state=state_input

# %%
# Simulation data load from IEEE 39-bus system
data = loadmat('/content/drive/MyDrive/Colab Notebooks/RL_for_Optimal_Frequency_Control/data/IEEE-39-adjacency-matrix.mat')
D=data['D']
D=np.asarray(D)

data = loadmat('/content/drive/MyDrive/Colab Notebooks/RL_for_Optimal_Frequency_Control/data/IEEE-39-power-initial-balanced.mat')
Power_initial=data['power_initial']
Power_initial=np.asarray(Power_initial)

data = loadmat('/content/drive/MyDrive/Colab Notebooks/RL_for_Optimal_Frequency_Control/data/IEEE-39-rotational-inertial-generator.mat')
Rotational_inertial_generator=data['rotational_inertial_generator']
Rotational_inertial_generator=np.asarray(Rotational_inertial_generator)

data = loadmat('/content/drive/MyDrive/Colab Notebooks/RL_for_Optimal_Frequency_Control/data/IEEE-39-rotational-inertial-load.mat')
Rotational_inertial_load=data['rotational_inertial_load']
Rotational_inertial_load=np.asarray(Rotational_inertial_load)

data = loadmat('/content/drive/MyDrive/Colab Notebooks/RL_for_Optimal_Frequency_Control/data/IEEE-39-susceptance-matrix.mat')
D_reactance=data['D_reactance']
D_reactance=np.asarray(D_reactance)

# %%
dim_omega=39 #dimension of action space
dim_lambda=46 #dimension of lambda
dim_state=dim_omega+dim_lambda #dimension of state space
action_units=dim_omega
delta_t=0.0008
M=((np.vstack((Rotational_inertial_load,Rotational_inertial_generator)))[:,1]).reshape(1,dim_omega)
E=1*np.ones((1,dim_omega),dtype=np.float32)
L=np.transpose(D)@(D_reactance)@D
Laplacian=np.transpose(D)@D
A_nom=-Laplacian+np.diag(np.diag(Laplacian))
syn_frequence=np.sum(Power_initial,axis=0)/np.sum(E,axis=1)
f_initial=D@np.linalg.pinv(L)@(Power_initial-syn_frequence*np.transpose(E))
Pm=np.transpose(Power_initial)
Pm_nominal=copy.deepcopy(Pm)
omega_max=0.2
omega_min=-0.2
#Penalty_action=40
Penalty_action=40*200
equilibrium_init=np.hstack((np.transpose(f_initial),syn_frequence*np.ones((1,dim_omega))))
env = Transient_Frequency(M,E,Pm,D,D_reactance,delta_t,omega_max,omega_min,dim_omega,dim_lambda,Penalty_action)

# %% [markdown]
# # Init Simulation

# %%
#Controller in Zhang & Cortes (2019)
def Action_Yifu(state,env):
    states_controlled=state@env.select_omega
    alpha_plus = 2*(states_controlled-omega_max*np.ones((dim_omega,)))
    alpha_minus = 2*(omega_min*np.ones((dim_omega,))-states_controlled)
    q_xp = E*states_controlled+(np.sin(state@env.select_lambda)@D_reactance)@D-Pm
    omega_th_max=(0.5*omega_max*np.ones((dim_omega,)))
    omega_th_min=(0.5*omega_min*np.ones((dim_omega,)))
    def getBinaryNumpy(imgNumpy, boundary=0):
        one = np.ones_like(imgNumpy)
        zero = np.zeros_like(imgNumpy)
        return np.where(imgNumpy>boundary, one, zero)
    nonlinear_plus = getBinaryNumpy(states_controlled-omega_th_max, boundary=0)*\
      np.minimum(np.zeros(dim_omega,), -alpha_plus*((states_controlled-omega_th_max)**(-1))+q_xp)
    nonlinear_minus = getBinaryNumpy(omega_th_min-state@env.select_omega, boundary=0)*\
      np.maximum(np.zeros(dim_omega,), alpha_minus*((omega_th_min-states_controlled)**(-1))+q_xp)

    action = nonlinear_plus + nonlinear_minus
    return action

# %%
# Plot the trajectory to visulize the performance of control

Trajectory_Linear_omega=[]
Trajectory_Linear_omega_true=[]
Trajectory_Linear_lambda=[]

initial_state1=np.transpose(D@np.linalg.pinv(L)@(Power_initial*np.random.uniform(-0.1,0.1,(dim_omega,1))-syn_frequence*np.transpose(E)))
initial_state2=np.random.uniform(-0.1,0.1,(1,dim_omega))*1
s_concate=np.hstack((initial_state1,initial_state2)).astype(np.float32)

init_state=equilibrium_init + s_concate
#
s=init_state
s_record_all_omega = s@env.select_omega
s_record_all_omega_true = s_record_all_omega + 60*np.ones((1,dim_omega))
s_record_all_lambda = s@env.select_lambda
env.set_state(s)
Trajectory_Linear_omega.append(s_record_all_omega)
Trajectory_Linear_omega_true.append(s_record_all_omega_true)
Trajectory_Linear_lambda.append(s_record_all_lambda)
Test_time=50
SimulationLength=int(Test_time/delta_t)
Record_u_Linear=[]
Record_Loss_Linear=[]
Loss_Linear=0

generator_loss_node = 38
# generator_loss_node_1 = 38
# generator_loss_node_2 = 35
# generator_loss_node_3 = 33
# generator_loss_node_4 = 32

generator_loss_start_time = 0
generator_loss_period = 2
for i in range(SimulationLength):
    if i>=generator_loss_start_time/delta_t and i<=(generator_loss_start_time+generator_loss_period)/delta_t:
      Pm[0,generator_loss_node-1] = 0
      # Pm[0,generator_loss_node_1-1] = 0
      # Pm[0,generator_loss_node_2-1] = 0
      # Pm[0,generator_loss_node_3-1] = 0
      # Pm[0,generator_loss_node_4-1] = 0
    else:
      Pm[0,generator_loss_node-1] = Pm_nominal[0,generator_loss_node-1]
      # Pm[0,generator_loss_node_1-1] = Pm_nominal[0,generator_loss_node_1-1]
      # Pm[0,generator_loss_node_2-1] = Pm_nominal[0,generator_loss_node_2-1]
      # Pm[0,generator_loss_node_3-1] = Pm_nominal[0,generator_loss_node_3-1]
      # Pm[0,generator_loss_node_4-1] = Pm_nominal[0,generator_loss_node_4-1]
    u=Action_Yifu(s,env)
    next_s, r= env.step(u,Pm)
    Loss_Linear+=r
    s=next_s
    s_record_all_omega = s@env.select_omega
    s_record_all_omega_true = s_record_all_omega + 60*np.ones((1,dim_omega))
    s_record_all_lambda = s@env.select_lambda
    Trajectory_Linear_omega.append(s_record_all_omega)
    Trajectory_Linear_omega_true.append(s_record_all_omega_true)
    Trajectory_Linear_lambda.append(s_record_all_lambda)
    Record_u_Linear.append(u)
    Record_Loss_Linear.append(np.squeeze(r))

Trajectory_Linear_omega=np.squeeze(np.asarray(Trajectory_Linear_omega))
Trajectory_Linear_omega_true=np.squeeze(np.asarray(Trajectory_Linear_omega_true))
Trajectory_Linear_lambda=np.squeeze(np.asarray(Trajectory_Linear_lambda))
Record_u_Linear=np.squeeze(np.asarray(Record_u_Linear))

plt.figure(figsize=(18,4), dpi=100)
TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=env.delta_t*TimeRecord
plt.subplot(1,3,1)

plt.plot(TimeRecord,Record_u_Linear)
plt.grid()
plt.xlabel('Time (s)', fontsize=14)
plt.ylabel('Control action (p.u.)', fontsize=14)


plt.subplot(1,3,2)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=env.delta_t*TimeRecord

plt.plot(TimeRecord,Trajectory_Linear_omega_true)
plt.grid()
plt.xlabel('Time (s)', fontsize=14)
plt.ylabel('$\omega$ (rad/s)', fontsize=14)


plt.subplot(1,3,3)
TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=env.delta_t*TimeRecord

plt.plot(TimeRecord,Trajectory_Linear_lambda)
plt.grid()
plt.xlabel('Time (s)', fontsize=14)
plt.ylabel('$\lambda$ (rad)', fontsize=14)
init_state
# Out:
# <>:84: DeprecationWarning: invalid escape sequence \o
# <>:94: DeprecationWarning: invalid escape sequence \l
# array([[-0.0549860327543785,  0.0335544128965761,  0.0572010971233727,
#         -0.0233855134714741, -0.0434843307929113,  0.0221898663854743,
#         -0.0074500711111365, -0.018533718792206 , -0.0338461106072189,
#          0.0370892371173328,  0.0123634393389667,  0.0404500601334751,
#         -0.0279888204355489,  0.0090026163664802, -0.0056338765018836,
#         -0.0037721593318898,  0.0147038754146575,  0.0120693846588925,
#         -0.12444045452401  , -0.0004590103400685, -0.0030935010812816,
#          0.0276743588171309,  0.0026175156398474, -0.0315592472883052,
#          0.0157484628381164, -0.0831135105134278, -0.0449341797832499,
#         -0.003098674710247 ,  0.0173994421101244, -0.0060217169045757,
#         -0.0888683176045828,  0.0276057650700972, -0.0969626352997125,
#         -0.08219216836182  ,  0.0074587577423864, -0.095002139490843 ,
#          0.1165689156851604, -0.1380493097302319,  0.0071715823779684,
#         -0.1247826903925461,  0.0425437975671729, -0.0844660996136817,
#         -0.1411729956973495, -0.0567068956180065, -0.1360340196374061,
#          0.1433581756158323, -0.0553875453770161,  0.0306235887110233,
#          0.0591499507427216, -0.013453439809382 , -0.0680153667926788,
#         -0.0845162943005562,  0.0909160226583481,  0.0409371741116047,
#         -0.0966507717967033,  0.0426850467920303, -0.0559541136026382,
#         -0.0631789341568947, -0.0244432091712952,  0.0877501890063286,
#          0.0705710798501968,  0.042555708438158 , -0.0163063537329435,
#          0.0430759973824024, -0.0576665252447128,  0.0172585994005203,
#         -0.018056308850646 ,  0.0144650293514132, -0.0906124785542488,
#          0.0468394607305527,  0.0583987310528755,  0.0822074115276337,
#         -0.0179139487445354, -0.021043298766017 , -0.0226553827524185,
#          0.068418376147747 , -0.0033488222397864,  0.0397690273821354,
#         -0.0349111184477806,  0.0831582099199295, -0.0040347171016037,
#          0.0954496413469315, -0.0050658429972827, -0.0575947649776936,
#          0.0678567811846733]])

# %%
(np.sum(np.power(Record_u_Linear,2))+env.Penalty_action*np.sum(np.power(Trajectory_Linear_omega,2)))/(50/0.0008)

# %% [markdown]
# # RNN

# %%
# RNN Cell to integrate state transition dynamics
global count_num
count_num=0

class MinimalRNNCell(keras.layers.Layer):

    def __init__(self,units,action_units,internal_units,env,batchsize,**kwargs):
        self.units = units
        self.state_size = units
        self.action_units = action_units
        self.internal_units = internal_units
        self.batchsize=batchsize
        self.state_transfer1=tf.constant(env.state_transfer1,dtype=tf.float32)
        self.state_transfer2=tf.constant(env.state_transfer2,dtype=tf.float32)
        self.state_transfer3=tf.constant(env.state_transfer3,dtype=tf.float32)
        self.select_add_omega=tf.constant(env.select_add_omega,dtype=tf.float32)
        self.select_omega=tf.constant(env.select_omega,dtype=tf.float32)
        self.select_lambda=tf.constant(env.select_lambda,dtype=tf.float32)
        self.weight_recover=tf.constant(tf.linalg.band_part(-tf.ones((internal_units,internal_units),dtype=tf.float32),0,1)\
                                        +2*tf.eye(internal_units,dtype=tf.float32),dtype=tf.float32)
        self.bias_recover=tf.constant(tf.linalg.band_part(tf.ones((internal_units,internal_units),dtype=tf.float32),0,-1)\
                                        -tf.eye(internal_units,dtype=tf.float32),dtype=tf.float32)
        self.ones_frequency=tf.ones((action_units,internal_units),dtype=np.float32)
        super(MinimalRNNCell, self).__init__(**kwargs)

    def build(self, input_shape):

        #alpha_plus and alpha_minus
        self.w_plus_temp0= self.add_weight(
            shape=(self.action_units,self.internal_units),
            initializer='uniform',
            trainable=True,
            name='w_plus_temp')

        self.b_plus_temp0 = self.add_weight(
            shape=(self.action_units,self.internal_units),
            initializer=tf.keras.initializers.RandomUniform(minval=0, maxval=0.1),
            trainable=True,
            constraint=tf.keras.constraints.MaxNorm(0.2),
            name='b_plus_temp')

        self.w_minus_temp0= self.add_weight(
            shape=(self.action_units,self.internal_units),
            initializer='uniform',
            trainable=True,
            name='w_minus_temp')

        self.b_minus_temp0 = self.add_weight(
            shape=(self.action_units,self.internal_units),
            initializer=tf.keras.initializers.RandomUniform(minval=0, maxval=0.1),
            trainable=True,
            constraint=tf.keras.constraints.MaxNorm(0.2),
            name='b_minus_temp')

        #omega_threshold
        self.t_plus_temp= self.add_weight(
            shape=(self.action_units,),
            initializer=tf.keras.initializers.RandomUniform(minval=0, maxval=0),
            trainable=True,
            name='t_plus_temp')

        self.t_minus_temp= self.add_weight(
            shape=(self.action_units,),
            initializer=tf.keras.initializers.RandomUniform(minval=0, maxval=0),
            trainable=True,
            name='t_minus_temp')

        #budgets

        self.d_temp= self.add_weight(
            shape=(1,self.action_units),
            initializer=tf.keras.initializers.RandomUniform(minval=0, maxval=0),
            trainable=True,
            # constraint=tf.keras.constraints.MaxNorm(0.001),
            name='d_temp')

        #controls
        self.q_plus_temp0= self.add_weight(
            shape=(self.action_units,self.internal_units),
            initializer='uniform',
            trainable=True,
            name='q_plus_temp')

        self.c_plus_temp0 = self.add_weight(
            shape=(self.action_units,self.internal_units),
            initializer=tf.keras.initializers.RandomUniform(minval=-0.1, maxval=0.1),
            trainable=True,
            constraint=tf.keras.constraints.MaxNorm(0.2),
            name='c_plus_temp')

        self.q_minus_temp0= self.add_weight(
            shape=(self.action_units,self.internal_units),
            initializer='uniform',
            trainable=True,
            name='q_minus_temp')

        self.c_minus_temp0 = self.add_weight(
            shape=(self.action_units,self.internal_units),
            initializer=tf.keras.initializers.RandomUniform(minval=-0.1, maxval=0.1),
            trainable=True,
            constraint=tf.keras.constraints.MaxNorm(0.2),
            name='c_minus_temp')

        self.built = True

    def call(self, inputs, states):
        # stacked ReLU structure to represent control network
        global count_num
        if count_num < int(T/2):
          Pm[0,37] = 0
          # Pm[0,34] = 0
          # Pm[0,32] = 0
          # Pm[0,31] = 0
        else:
          Pm[0,37] = Pm_nominal[0,37]
          # Pm[0,34] = Pm_nominal[0,34]
          # Pm[0,32] = Pm_nominal[0,32]
          # Pm[0,31] = Pm_nominal[0,31]
        ################################################################################### Multiple generator loss
        prev_output = states[0]
        w_plus_temp=tf.math.abs(self.w_plus_temp0)
        b_plus_temp=tf.math.abs(self.b_plus_temp0)
        w_minus_temp=tf.math.abs(self.w_minus_temp0)
        b_minus_temp=tf.math.abs(self.b_minus_temp0)
        w_plus=K.dot(-w_plus_temp,self.weight_recover)
        b_plus=K.dot(-b_plus_temp,self.bias_recover)
        w_minus=K.dot(-w_minus_temp,self.weight_recover)
        b_minus=K.dot(-b_minus_temp,self.bias_recover)

        d=K.dot(self.d_temp,tf.eye(self.action_units,dtype=tf.float32))

        q_plus=self.q_plus_temp0
        c_plus=-tf.math.abs(self.c_plus_temp0)
        q_minus=self.q_minus_temp0
        c_minus=-tf.math.abs(self.c_minus_temp0)

        omega_th_max=omega_max*K.sigmoid(self.t_plus_temp)
        omega_th_min=omega_min*K.sigmoid(self.t_minus_temp)

        treshold_min_square=tf.math.minimum(omega_th_max**(2),omega_th_min**(2))

        def getBinaryTensor(imgTensor,boundary=0):
          one = tf.ones_like(imgTensor, dtype=tf.float32)
          zero = tf.zeros_like(imgTensor)
          return tf.where(imgTensor > boundary, one, zero)

        states_controlled = K.dot(prev_output,self.select_omega)

        status=getBinaryTensor(states_controlled-omega_th_max)+getBinaryTensor(omega_th_min-states_controlled)
        status_new=tf.linalg.diag(status)
        A_tilde=status_new@A_nom@status_new
        Laplacian_tilde_diag=K.sum(A_tilde,axis=2)
        Laplacian_tilde=-A_tilde+tf.linalg.diag(Laplacian_tilde_diag)

        budgets_temp=d@Laplacian_tilde
        scale = tf.math.reduce_max(-budgets_temp/treshold_min_square, axis=2)

        def getBinaryScale(Tensor,boundary=1):
          one = tf.ones_like(Tensor, dtype=tf.float32)
          scale_factor = tf.ones_like(Tensor)
          return tf.where(Tensor > boundary, Tensor, one)

        # budgets=(budgets_temp/(tf.math.reduce_max(-budgets_temp/(treshold_min_square))+1e-8))
        scale_new = tf.linalg.diag(getBinaryScale(scale))@tf.ones((1,dim_omega))
        budgets=tf.squeeze(budgets_temp/scale_new)

        alpha_plus = K.sum(K.relu(-K.dot(tf.linalg.diag(states_controlled-env.omega_max*tf.ones((self.action_units,))),self.ones_frequency)+b_plus)*w_plus,axis=2)
        alpha_minus = K.sum(K.relu(-K.dot(tf.linalg.diag(env.omega_min*tf.ones((self.action_units,))-states_controlled),self.ones_frequency)+b_minus)*w_minus,axis=2)

        q_xp = env.E*states_controlled+(K.sin(K.dot(prev_output,self.select_lambda))@D_reactance)@D-np.squeeze(Pm)

        control_plus = K.sum(K.relu(K.dot(tf.linalg.diag(states_controlled-omega_th_max),self.ones_frequency)+c_plus)*q_plus,axis=2)
        control_minus = K.sum(K.relu(-K.dot(tf.linalg.diag(states_controlled-omega_th_min),self.ones_frequency)+c_minus)*q_minus,axis=2)

        nonlinear_plus = getBinaryTensor(states_controlled-omega_th_max, boundary=0)*\
                    tf.math.minimum(tf.math.minimum(states_controlled+budgets*((states_controlled+1e-8)**(-1)), control_plus+control_minus), -alpha_plus*((states_controlled-omega_th_max+1e-8)**(-1))+q_xp)
        nonlinear_minus = getBinaryTensor(omega_th_min-states_controlled, boundary=0)*\
                    tf.math.maximum(tf.math.maximum(states_controlled+budgets*((states_controlled+1e-8)**(-1)), control_plus+control_minus), alpha_minus*((omega_th_min-states_controlled+1e-8)**(-1))+q_xp)
        #
        action = nonlinear_plus + nonlinear_minus

        # action = tf.math.minimum(tf.math.maximum(-3*tf.ones((1,dim_omega)),action),3*tf.ones((1,dim_omega))) ### projection

        # integrate the state transition dynamics

        new_state = prev_output@self.state_transfer1 \
                -((delta_t*((K.sin(K.dot(prev_output,self.select_lambda)))@D_reactance)@D)*(M**(-1)))@self.state_transfer2 \
                    + (np.ones((self.batchsize,1),dtype=np.float32)@Pm+action)@self.state_transfer3

        loss0 = K.dot(K.pow(new_state,2),self.select_add_omega)
        frequency=K.dot(new_state,self.select_omega)

        count_num+=1
        if count_num == T-1:
          print("One Episode Ended")
          count_num=0

        return [loss0,frequency,action], [new_state]

# %%
start = time.time()

episodes = 100 # total number of iterations to update weights
action_units=dim_omega
units=dim_omega+dim_lambda #dimension of each state
internal_units=20 # demension of the neural network for control policy
T=5000  #Total period considered
Batch_num=50 # number of batch in each episodes 60
#loss_distribution=np.ones((Batch_num,dim_omega), dtype=np.float64)
cell = MinimalRNNCell(units,action_units,internal_units,env,Batch_num)
layer = RNN(cell,return_sequences=True,stateful = True)
input_1 = tf.keras.Input(batch_shape=(Batch_num,T,units))
outputs = layer((input_1))
model = tf.keras.models.Model([input_1], outputs)
model.compile(optimizer='Adam', loss='mse', metrics=['accuracy'])

x0=np.ones((Batch_num,T,units))
y0=model(x0)
Loss_record=[]
Pe_rnn_record=[]
global_step = tf.Variable(0, trainable=False)
learning_rate_initial=0.2
# decayed_lr =tf.keras.optimizers.schedules.ExponentialDecay(
#     learning_rate_initial, 1, 0.96, staircase=True)
optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_initial)
PrintUpdate=1
delta_rnn_init_bound=0
omega_rnn_init_bound=0.1 #in Hz

for i in range(0,episodes):
    initial_state1=np.transpose(D@np.linalg.pinv(L)@(Power_initial*np.random.uniform(-0.1,0.1,(dim_omega,Batch_num))-syn_frequence*1*np.ones((dim_omega,Batch_num),dtype=np.float32)))
    initial_state2=np.random.uniform(-omega_rnn_init_bound,omega_rnn_init_bound,(Batch_num,action_units))
    initial_state=np.hstack((initial_state1,initial_state2)) + np.ones((Batch_num,1))@equilibrium_init
    layer.reset_states(initial_state)
    with tf.GradientTape(persistent=True) as tape:
        [loss0,frequency,action]=model(x0)
        loss=0.1*(env.Penalty_action*K.sum(K.max(K.abs(frequency),axis=1))+K.sum(K.pow(action,2)))/(Batch_num*T)
        #K.max(K.abs(frequency),axis=1)
        #K.sum(K.pow(frequency,2))
    grads = tape.gradient(loss, model.variables)
    optimizer.apply_gradients(zip(grads, model.variables))
    Loss_record.append(loss)
    if i % (PrintUpdate) == 0:
        print('episode',i, 'Loss',loss)
        print('episode',i, 'Loss_frequency',(env.Penalty_action*K.sum(K.max(K.abs(frequency),axis=1)))/(Batch_num*T))
        print('episode',i, 'Loss_action',(K.sum(K.pow(action,2)))/(Batch_num*T))

end = time.time()
print(end - start)
# Out:
# One Episode Ended
# One Episode Ended
# episode 0 Loss tf.Tensor(1.4606844, shape=(), dtype=float32)
# episode 0 Loss_frequency tf.Tensor(6.9678807, shape=(), dtype=float32)
# episode 0 Loss_action tf.Tensor(7.638963, shape=(), dtype=float32)
# One Episode Ended
# episode 1 Loss tf.Tensor(1.4292816, shape=(), dtype=float32)
# episode 1 Loss_frequency tf.Tensor(7.2777705, shape=(), dtype=float32)
# episode 1 Loss_action tf.Tensor(7.015046, shape=(), dtype=float32)
# One Episode Ended
# episode 2 Loss tf.Tensor(1.3790289, shape=(), dtype=float32)
# episode 2 Loss_frequency tf.Tensor(7.110655, shape=(), dtype=float32)
# episode 2 Loss_action tf.Tensor(6.679633, shape=(), dtype=float32)
# One Episode Ended
# episode 3 Loss tf.Tensor(1.3240418, shape=(), dtype=float32)
# episode 3 Loss_frequency tf.Tensor(6.65959, shape=(), dtype=float32)
# episode 3 Loss_action tf.Tensor(6.5808277, shape=(), dtype=float32)
# One Episode Ended
# episode 4 Loss tf.Tensor(1.294454, shape=(), dtype=float32)
# episode 4 Loss_frequency tf.Tensor(6.4018645, shape=(), dtype=float32)
# episode 4 Loss_action tf.Tensor(6.5426755, shape=(), dtype=float32)
# One Episode Ended
# episode 5 Loss tf.Tensor(1.2734476, shape=(), dtype=float32)
# episode 5 Loss_frequency tf.Tensor(6.1721897, shape=(), dtype=float32)
# episode 5 Loss_action tf.Tensor(6.562287, shape=(), dtype=float32)
# One Episode Ended
# episode 6 Loss tf.Tensor(1.2672867, shape=(), dtype=float32)
# episode 6 Loss_frequency tf.Tensor(6.124516, shape=(), dtype=float32)
# episode 6 Loss_action tf.Tensor(6.54835, shape=(), dtype=float32)
# One Episode Ended
# episode 7 Loss tf.Tensor(1.2441094, shape=(), dtype=float32)
# episode 7 Loss_frequency tf.Tensor(5.8734245, shape=(), dtype=float32)
# episode 7 Loss_action tf.Tensor(6.567669, shape=(), dtype=float32)
# One Episode Ended
# episode 8 Loss tf.Tensor(1.2240763, shape=(), dtype=float32)
# episode 8 Loss_frequency tf.Tensor(5.612112, shape=(), dtype=float32)
# episode 8 Loss_action tf.Tensor(6.6286497, shape=(), dtype=float32)
# One Episode Ended
# episode 9 Loss tf.Tensor(1.2086695, shape=(), dtype=float32)
# episode 9 Loss_frequency tf.Tensor(5.419642, shape=(), dtype=float32)
# episode 9 Loss_action tf.Tensor(6.667053, shape=(), dtype=float32)
# One Episode Ended
# episode 10 Loss tf.Tensor(1.193004, shape=(), dtype=float32)
# episode 10 Loss_frequency tf.Tensor(5.301489, shape=(), dtype=float32)
# episode 10 Loss_action tf.Tensor(6.6285515, shape=(), dtype=float32)
# One Episode Ended
# episode 11 Loss tf.Tensor(1.1769993, shape=(), dtype=float32)
# episode 11 Loss_frequency tf.Tensor(5.1765065, shape=(), dtype=float32)
# episode 11 Loss_action tf.Tensor(6.593488, shape=(), dtype=float32)
# One Episode Ended
# episode 12 Loss tf.Tensor(1.1772039, shape=(), dtype=float32)
# episode 12 Loss_frequency tf.Tensor(5.090928, shape=(), dtype=float32)
# episode 12 Loss_action tf.Tensor(6.6811104, shape=(), dtype=float32)
# One Episode Ended
# episode 13 Loss tf.Tensor(1.1674854, shape=(), dtype=float32)
# episode 13 Loss_frequency tf.Tensor(5.0079026, shape=(), dtype=float32)
# episode 13 Loss_action tf.Tensor(6.6669517, shape=(), dtype=float32)
# One Episode Ended
# episode 14 Loss tf.Tensor(1.1590954, shape=(), dtype=float32)
# episode 14 Loss_frequency tf.Tensor(4.8482966, shape=(), dtype=float32)
# episode 14 Loss_action tf.Tensor(6.7426577, shape=(), dtype=float32)
# One Episode Ended
# episode 15 Loss tf.Tensor(1.1515934, shape=(), dtype=float32)
# episode 15 Loss_frequency tf.Tensor(4.784796, shape=(), dtype=float32)
# episode 15 Loss_action tf.Tensor(6.731139, shape=(), dtype=float32)
# One Episode Ended
# episode 16 Loss tf.Tensor(1.150485, shape=(), dtype=float32)
# episode 16 Loss_frequency tf.Tensor(4.7659636, shape=(), dtype=float32)
# episode 16 Loss_action tf.Tensor(6.7388864, shape=(), dtype=float32)
# One Episode Ended
# episode 17 Loss tf.Tensor(1.1476846, shape=(), dtype=float32)
# episode 17 Loss_frequency tf.Tensor(4.6983776, shape=(), dtype=float32)
# episode 17 Loss_action tf.Tensor(6.778468, shape=(), dtype=float32)
# One Episode Ended
# episode 18 Loss tf.Tensor(1.1405724, shape=(), dtype=float32)
# episode 18 Loss_frequency tf.Tensor(4.5983543, shape=(), dtype=float32)
# episode 18 Loss_action tf.Tensor(6.80737, shape=(), dtype=float32)
# One Episode Ended
# episode 19 Loss tf.Tensor(1.1273829, shape=(), dtype=float32)
# episode 19 Loss_frequency tf.Tensor(4.488382, shape=(), dtype=float32)
# episode 19 Loss_action tf.Tensor(6.785446, shape=(), dtype=float32)
# One Episode Ended
# episode 20 Loss tf.Tensor(1.1329081, shape=(), dtype=float32)
# episode 20 Loss_frequency tf.Tensor(4.4662704, shape=(), dtype=float32)
# episode 20 Loss_action tf.Tensor(6.8628106, shape=(), dtype=float32)
# One Episode Ended
# episode 21 Loss tf.Tensor(1.1256875, shape=(), dtype=float32)
# episode 21 Loss_frequency tf.Tensor(4.385316, shape=(), dtype=float32)
# episode 21 Loss_action tf.Tensor(6.871559, shape=(), dtype=float32)
# One Episode Ended
# episode 22 Loss tf.Tensor(1.1254898, shape=(), dtype=float32)
# episode 22 Loss_frequency tf.Tensor(4.349242, shape=(), dtype=float32)
# episode 22 Loss_action tf.Tensor(6.905657, shape=(), dtype=float32)
# One Episode Ended
# episode 23 Loss tf.Tensor(1.1395466, shape=(), dtype=float32)
# episode 23 Loss_frequency tf.Tensor(4.38709, shape=(), dtype=float32)
# episode 23 Loss_action tf.Tensor(7.0083766, shape=(), dtype=float32)
# One Episode Ended
# episode 24 Loss tf.Tensor(1.127029, shape=(), dtype=float32)
# episode 24 Loss_frequency tf.Tensor(4.324071, shape=(), dtype=float32)
# episode 24 Loss_action tf.Tensor(6.946219, shape=(), dtype=float32)
# One Episode Ended
# episode 25 Loss tf.Tensor(1.1273829, shape=(), dtype=float32)
# episode 25 Loss_frequency tf.Tensor(4.2768645, shape=(), dtype=float32)
# episode 25 Loss_action tf.Tensor(6.9969645, shape=(), dtype=float32)
# One Episode Ended
# episode 26 Loss tf.Tensor(1.1320099, shape=(), dtype=float32)
# episode 26 Loss_frequency tf.Tensor(4.2605586, shape=(), dtype=float32)
# episode 26 Loss_action tf.Tensor(7.0595403, shape=(), dtype=float32)
# One Episode Ended
# episode 27 Loss tf.Tensor(1.1284009, shape=(), dtype=float32)
# episode 27 Loss_frequency tf.Tensor(4.241416, shape=(), dtype=float32)
# episode 27 Loss_action tf.Tensor(7.0425916, shape=(), dtype=float32)
# One Episode Ended
# episode 28 Loss tf.Tensor(1.1222049, shape=(), dtype=float32)
# episode 28 Loss_frequency tf.Tensor(4.22824, shape=(), dtype=float32)
# episode 28 Loss_action tf.Tensor(6.9938073, shape=(), dtype=float32)
# One Episode Ended
# episode 29 Loss tf.Tensor(1.1260669, shape=(), dtype=float32)
# episode 29 Loss_frequency tf.Tensor(4.1953306, shape=(), dtype=float32)
# episode 29 Loss_action tf.Tensor(7.0653377, shape=(), dtype=float32)
# One Episode Ended
# episode 30 Loss tf.Tensor(1.1206504, shape=(), dtype=float32)
# episode 30 Loss_frequency tf.Tensor(4.20386, shape=(), dtype=float32)
# episode 30 Loss_action tf.Tensor(7.002644, shape=(), dtype=float32)
# One Episode Ended
# episode 31 Loss tf.Tensor(1.1247272, shape=(), dtype=float32)
# episode 31 Loss_frequency tf.Tensor(4.2016764, shape=(), dtype=float32)
# episode 31 Loss_action tf.Tensor(7.0455956, shape=(), dtype=float32)
# One Episode Ended
# episode 32 Loss tf.Tensor(1.109303, shape=(), dtype=float32)
# episode 32 Loss_frequency tf.Tensor(4.13613, shape=(), dtype=float32)
# episode 32 Loss_action tf.Tensor(6.9568996, shape=(), dtype=float32)
# One Episode Ended
# episode 33 Loss tf.Tensor(1.110924, shape=(), dtype=float32)
# episode 33 Loss_frequency tf.Tensor(4.1561337, shape=(), dtype=float32)
# episode 33 Loss_action tf.Tensor(6.9531064, shape=(), dtype=float32)
# One Episode Ended
# episode 34 Loss tf.Tensor(1.1216099, shape=(), dtype=float32)
# episode 34 Loss_frequency tf.Tensor(4.219541, shape=(), dtype=float32)
# episode 34 Loss_action tf.Tensor(6.996558, shape=(), dtype=float32)
# One Episode Ended
# episode 35 Loss tf.Tensor(1.113681, shape=(), dtype=float32)
# episode 35 Loss_frequency tf.Tensor(4.16305, shape=(), dtype=float32)
# episode 35 Loss_action tf.Tensor(6.9737597, shape=(), dtype=float32)
# One Episode Ended
# episode 36 Loss tf.Tensor(1.1208906, shape=(), dtype=float32)
# episode 36 Loss_frequency tf.Tensor(4.207583, shape=(), dtype=float32)
# episode 36 Loss_action tf.Tensor(7.001323, shape=(), dtype=float32)
# One Episode Ended
# episode 37 Loss tf.Tensor(1.1029133, shape=(), dtype=float32)
# episode 37 Loss_frequency tf.Tensor(4.116846, shape=(), dtype=float32)
# episode 37 Loss_action tf.Tensor(6.912286, shape=(), dtype=float32)
# One Episode Ended
# episode 38 Loss tf.Tensor(1.1054202, shape=(), dtype=float32)
# episode 38 Loss_frequency tf.Tensor(4.1520147, shape=(), dtype=float32)
# episode 38 Loss_action tf.Tensor(6.902187, shape=(), dtype=float32)
# One Episode Ended
# episode 39 Loss tf.Tensor(1.1157672, shape=(), dtype=float32)
# episode 39 Loss_frequency tf.Tensor(4.167501, shape=(), dtype=float32)
# episode 39 Loss_action tf.Tensor(6.9901714, shape=(), dtype=float32)
# One Episode Ended
# episode 40 Loss tf.Tensor(1.1002305, shape=(), dtype=float32)
# episode 40 Loss_frequency tf.Tensor(4.106742, shape=(), dtype=float32)
# episode 40 Loss_action tf.Tensor(6.895563, shape=(), dtype=float32)
# One Episode Ended
# episode 41 Loss tf.Tensor(1.0933368, shape=(), dtype=float32)
# episode 41 Loss_frequency tf.Tensor(4.1137757, shape=(), dtype=float32)
# episode 41 Loss_action tf.Tensor(6.819592, shape=(), dtype=float32)
# One Episode Ended
# episode 42 Loss tf.Tensor(1.1126246, shape=(), dtype=float32)
# episode 42 Loss_frequency tf.Tensor(4.142151, shape=(), dtype=float32)
# episode 42 Loss_action tf.Tensor(6.9840946, shape=(), dtype=float32)
# One Episode Ended
# episode 43 Loss tf.Tensor(1.1108439, shape=(), dtype=float32)
# episode 43 Loss_frequency tf.Tensor(4.107376, shape=(), dtype=float32)
# episode 43 Loss_action tf.Tensor(7.0010614, shape=(), dtype=float32)
# One Episode Ended
# episode 44 Loss tf.Tensor(1.1005864, shape=(), dtype=float32)
# episode 44 Loss_frequency tf.Tensor(4.080678, shape=(), dtype=float32)
# episode 44 Loss_action tf.Tensor(6.9251866, shape=(), dtype=float32)
# One Episode Ended
# episode 45 Loss tf.Tensor(1.1012467, shape=(), dtype=float32)
# episode 45 Loss_frequency tf.Tensor(4.0915666, shape=(), dtype=float32)
# episode 45 Loss_action tf.Tensor(6.9209, shape=(), dtype=float32)
# One Episode Ended
# episode 46 Loss tf.Tensor(1.110412, shape=(), dtype=float32)
# episode 46 Loss_frequency tf.Tensor(4.117329, shape=(), dtype=float32)
# episode 46 Loss_action tf.Tensor(6.9867916, shape=(), dtype=float32)
# One Episode Ended
# episode 47 Loss tf.Tensor(1.0993322, shape=(), dtype=float32)
# episode 47 Loss_frequency tf.Tensor(4.09112, shape=(), dtype=float32)
# episode 47 Loss_action tf.Tensor(6.902202, shape=(), dtype=float32)
# One Episode Ended
# episode 48 Loss tf.Tensor(1.1080017, shape=(), dtype=float32)
# episode 48 Loss_frequency tf.Tensor(4.082284, shape=(), dtype=float32)
# episode 48 Loss_action tf.Tensor(6.997733, shape=(), dtype=float32)
# One Episode Ended
# episode 49 Loss tf.Tensor(1.0956012, shape=(), dtype=float32)
# episode 49 Loss_frequency tf.Tensor(4.0513916, shape=(), dtype=float32)
# episode 49 Loss_action tf.Tensor(6.9046206, shape=(), dtype=float32)
# One Episode Ended
# episode 50 Loss tf.Tensor(1.0869982, shape=(), dtype=float32)
# episode 50 Loss_frequency tf.Tensor(4.0633016, shape=(), dtype=float32)
# episode 50 Loss_action tf.Tensor(6.80668, shape=(), dtype=float32)
# One Episode Ended
# episode 51 Loss tf.Tensor(1.1070621, shape=(), dtype=float32)
# episode 51 Loss_frequency tf.Tensor(4.089099, shape=(), dtype=float32)
# episode 51 Loss_action tf.Tensor(6.981522, shape=(), dtype=float32)
# One Episode Ended
# episode 52 Loss tf.Tensor(1.1024084, shape=(), dtype=float32)
# episode 52 Loss_frequency tf.Tensor(4.063985, shape=(), dtype=float32)
# episode 52 Loss_action tf.Tensor(6.960099, shape=(), dtype=float32)
# One Episode Ended
# episode 53 Loss tf.Tensor(1.0964336, shape=(), dtype=float32)
# episode 53 Loss_frequency tf.Tensor(4.0830674, shape=(), dtype=float32)
# episode 53 Loss_action tf.Tensor(6.881269, shape=(), dtype=float32)
# One Episode Ended
# episode 54 Loss tf.Tensor(1.0869037, shape=(), dtype=float32)
# episode 54 Loss_frequency tf.Tensor(4.017363, shape=(), dtype=float32)
# episode 54 Loss_action tf.Tensor(6.851674, shape=(), dtype=float32)
# One Episode Ended
# episode 55 Loss tf.Tensor(1.0983641, shape=(), dtype=float32)
# episode 55 Loss_frequency tf.Tensor(4.0743804, shape=(), dtype=float32)
# episode 55 Loss_action tf.Tensor(6.909261, shape=(), dtype=float32)
# One Episode Ended
# episode 56 Loss tf.Tensor(1.0978544, shape=(), dtype=float32)
# episode 56 Loss_frequency tf.Tensor(4.054496, shape=(), dtype=float32)
# episode 56 Loss_action tf.Tensor(6.924047, shape=(), dtype=float32)
# One Episode Ended
# episode 57 Loss tf.Tensor(1.0876778, shape=(), dtype=float32)
# episode 57 Loss_frequency tf.Tensor(4.047475, shape=(), dtype=float32)
# episode 57 Loss_action tf.Tensor(6.829304, shape=(), dtype=float32)
# One Episode Ended
# episode 58 Loss tf.Tensor(1.099645, shape=(), dtype=float32)
# episode 58 Loss_frequency tf.Tensor(4.1103654, shape=(), dtype=float32)
# episode 58 Loss_action tf.Tensor(6.8860846, shape=(), dtype=float32)
# One Episode Ended
# episode 59 Loss tf.Tensor(1.0868989, shape=(), dtype=float32)
# episode 59 Loss_frequency tf.Tensor(4.065052, shape=(), dtype=float32)
# episode 59 Loss_action tf.Tensor(6.8039355, shape=(), dtype=float32)
# One Episode Ended
# episode 60 Loss tf.Tensor(1.0951991, shape=(), dtype=float32)
# episode 60 Loss_frequency tf.Tensor(4.0883384, shape=(), dtype=float32)
# episode 60 Loss_action tf.Tensor(6.8636527, shape=(), dtype=float32)
# One Episode Ended
# episode 61 Loss tf.Tensor(1.0942179, shape=(), dtype=float32)
# episode 61 Loss_frequency tf.Tensor(4.0616417, shape=(), dtype=float32)
# episode 61 Loss_action tf.Tensor(6.880536, shape=(), dtype=float32)
# One Episode Ended
# episode 62 Loss tf.Tensor(1.0969006, shape=(), dtype=float32)
# episode 62 Loss_frequency tf.Tensor(4.081416, shape=(), dtype=float32)
# episode 62 Loss_action tf.Tensor(6.88759, shape=(), dtype=float32)
# One Episode Ended
# episode 63 Loss tf.Tensor(1.0869466, shape=(), dtype=float32)
# episode 63 Loss_frequency tf.Tensor(4.0444236, shape=(), dtype=float32)
# episode 63 Loss_action tf.Tensor(6.8250427, shape=(), dtype=float32)
# One Episode Ended
# episode 64 Loss tf.Tensor(1.09636, shape=(), dtype=float32)
# episode 64 Loss_frequency tf.Tensor(4.0677633, shape=(), dtype=float32)
# episode 64 Loss_action tf.Tensor(6.8958364, shape=(), dtype=float32)
# One Episode Ended
# episode 65 Loss tf.Tensor(1.0905039, shape=(), dtype=float32)
# episode 65 Loss_frequency tf.Tensor(4.040132, shape=(), dtype=float32)
# episode 65 Loss_action tf.Tensor(6.8649054, shape=(), dtype=float32)
# One Episode Ended
# episode 66 Loss tf.Tensor(1.0933195, shape=(), dtype=float32)
# episode 66 Loss_frequency tf.Tensor(4.1027007, shape=(), dtype=float32)
# episode 66 Loss_action tf.Tensor(6.830494, shape=(), dtype=float32)
# One Episode Ended
# episode 67 Loss tf.Tensor(1.092657, shape=(), dtype=float32)
# episode 67 Loss_frequency tf.Tensor(4.085975, shape=(), dtype=float32)
# episode 67 Loss_action tf.Tensor(6.8405943, shape=(), dtype=float32)
# One Episode Ended
# episode 68 Loss tf.Tensor(1.0906318, shape=(), dtype=float32)
# episode 68 Loss_frequency tf.Tensor(4.0816216, shape=(), dtype=float32)
# episode 68 Loss_action tf.Tensor(6.8246975, shape=(), dtype=float32)
# One Episode Ended
# episode 69 Loss tf.Tensor(1.0852847, shape=(), dtype=float32)
# episode 69 Loss_frequency tf.Tensor(4.046939, shape=(), dtype=float32)
# episode 69 Loss_action tf.Tensor(6.805908, shape=(), dtype=float32)
# One Episode Ended
# episode 70 Loss tf.Tensor(1.0955213, shape=(), dtype=float32)
# episode 70 Loss_frequency tf.Tensor(4.0936565, shape=(), dtype=float32)
# episode 70 Loss_action tf.Tensor(6.8615575, shape=(), dtype=float32)
# One Episode Ended
# episode 71 Loss tf.Tensor(1.09481, shape=(), dtype=float32)
# episode 71 Loss_frequency tf.Tensor(4.084768, shape=(), dtype=float32)
# episode 71 Loss_action tf.Tensor(6.8633323, shape=(), dtype=float32)
# One Episode Ended
# episode 72 Loss tf.Tensor(1.086853, shape=(), dtype=float32)
# episode 72 Loss_frequency tf.Tensor(4.049754, shape=(), dtype=float32)
# episode 72 Loss_action tf.Tensor(6.8187757, shape=(), dtype=float32)
# One Episode Ended
# episode 73 Loss tf.Tensor(1.0811986, shape=(), dtype=float32)
# episode 73 Loss_frequency tf.Tensor(4.0418196, shape=(), dtype=float32)
# episode 73 Loss_action tf.Tensor(6.770166, shape=(), dtype=float32)
# One Episode Ended
# episode 74 Loss tf.Tensor(1.0680474, shape=(), dtype=float32)
# episode 74 Loss_frequency tf.Tensor(4.06921, shape=(), dtype=float32)
# episode 74 Loss_action tf.Tensor(6.611263, shape=(), dtype=float32)
# One Episode Ended
# episode 75 Loss tf.Tensor(1.0882987, shape=(), dtype=float32)
# episode 75 Loss_frequency tf.Tensor(4.1121535, shape=(), dtype=float32)
# episode 75 Loss_action tf.Tensor(6.770832, shape=(), dtype=float32)
# One Episode Ended
# episode 76 Loss tf.Tensor(1.0811743, shape=(), dtype=float32)
# episode 76 Loss_frequency tf.Tensor(4.0651417, shape=(), dtype=float32)
# episode 76 Loss_action tf.Tensor(6.7466006, shape=(), dtype=float32)
# One Episode Ended
# episode 77 Loss tf.Tensor(1.094319, shape=(), dtype=float32)
# episode 77 Loss_frequency tf.Tensor(4.0724926, shape=(), dtype=float32)
# episode 77 Loss_action tf.Tensor(6.8706975, shape=(), dtype=float32)
# One Episode Ended
# episode 78 Loss tf.Tensor(1.0953888, shape=(), dtype=float32)
# episode 78 Loss_frequency tf.Tensor(4.128596, shape=(), dtype=float32)
# episode 78 Loss_action tf.Tensor(6.8252916, shape=(), dtype=float32)
# One Episode Ended
# episode 79 Loss tf.Tensor(1.090914, shape=(), dtype=float32)
# episode 79 Loss_frequency tf.Tensor(4.1093554, shape=(), dtype=float32)
# episode 79 Loss_action tf.Tensor(6.799784, shape=(), dtype=float32)
# One Episode Ended
# episode 80 Loss tf.Tensor(1.0780681, shape=(), dtype=float32)
# episode 80 Loss_frequency tf.Tensor(4.0470657, shape=(), dtype=float32)
# episode 80 Loss_action tf.Tensor(6.733615, shape=(), dtype=float32)
# One Episode Ended
# episode 81 Loss tf.Tensor(1.0922395, shape=(), dtype=float32)
# episode 81 Loss_frequency tf.Tensor(4.10455, shape=(), dtype=float32)
# episode 81 Loss_action tf.Tensor(6.817845, shape=(), dtype=float32)
# One Episode Ended
# episode 82 Loss tf.Tensor(1.0887197, shape=(), dtype=float32)
# episode 82 Loss_frequency tf.Tensor(4.0746727, shape=(), dtype=float32)
# episode 82 Loss_action tf.Tensor(6.8125243, shape=(), dtype=float32)
# One Episode Ended
# episode 83 Loss tf.Tensor(1.083007, shape=(), dtype=float32)
# episode 83 Loss_frequency tf.Tensor(4.086968, shape=(), dtype=float32)
# episode 83 Loss_action tf.Tensor(6.7431026, shape=(), dtype=float32)
# One Episode Ended
# episode 84 Loss tf.Tensor(1.085537, shape=(), dtype=float32)
# episode 84 Loss_frequency tf.Tensor(4.0987496, shape=(), dtype=float32)
# episode 84 Loss_action tf.Tensor(6.756621, shape=(), dtype=float32)
# One Episode Ended
# episode 85 Loss tf.Tensor(1.0681666, shape=(), dtype=float32)
# episode 85 Loss_frequency tf.Tensor(4.034495, shape=(), dtype=float32)
# episode 85 Loss_action tf.Tensor(6.647171, shape=(), dtype=float32)
# One Episode Ended
# episode 86 Loss tf.Tensor(1.0774236, shape=(), dtype=float32)
# episode 86 Loss_frequency tf.Tensor(4.121463, shape=(), dtype=float32)
# episode 86 Loss_action tf.Tensor(6.652773, shape=(), dtype=float32)
# One Episode Ended
# episode 87 Loss tf.Tensor(1.0769533, shape=(), dtype=float32)
# episode 87 Loss_frequency tf.Tensor(4.105434, shape=(), dtype=float32)
# episode 87 Loss_action tf.Tensor(6.664098, shape=(), dtype=float32)
# One Episode Ended
# episode 88 Loss tf.Tensor(1.0899789, shape=(), dtype=float32)
# episode 88 Loss_frequency tf.Tensor(4.1261973, shape=(), dtype=float32)
# episode 88 Loss_action tf.Tensor(6.773591, shape=(), dtype=float32)
# One Episode Ended
# episode 89 Loss tf.Tensor(1.0798378, shape=(), dtype=float32)
# episode 89 Loss_frequency tf.Tensor(4.038636, shape=(), dtype=float32)
# episode 89 Loss_action tf.Tensor(6.759741, shape=(), dtype=float32)
# One Episode Ended
# episode 90 Loss tf.Tensor(1.0852704, shape=(), dtype=float32)
# episode 90 Loss_frequency tf.Tensor(4.100907, shape=(), dtype=float32)
# episode 90 Loss_action tf.Tensor(6.7517967, shape=(), dtype=float32)
# One Episode Ended
# episode 91 Loss tf.Tensor(1.0999383, shape=(), dtype=float32)
# episode 91 Loss_frequency tf.Tensor(4.114989, shape=(), dtype=float32)
# episode 91 Loss_action tf.Tensor(6.884393, shape=(), dtype=float32)
# One Episode Ended
# episode 92 Loss tf.Tensor(1.0797585, shape=(), dtype=float32)
# episode 92 Loss_frequency tf.Tensor(4.09274, shape=(), dtype=float32)
# episode 92 Loss_action tf.Tensor(6.7048445, shape=(), dtype=float32)
# One Episode Ended
# episode 93 Loss tf.Tensor(1.0763935, shape=(), dtype=float32)
# episode 93 Loss_frequency tf.Tensor(4.0546956, shape=(), dtype=float32)
# episode 93 Loss_action tf.Tensor(6.7092395, shape=(), dtype=float32)
# One Episode Ended
# episode 94 Loss tf.Tensor(1.0817624, shape=(), dtype=float32)
# episode 94 Loss_frequency tf.Tensor(4.0459886, shape=(), dtype=float32)
# episode 94 Loss_action tf.Tensor(6.7716346, shape=(), dtype=float32)
# One Episode Ended
# episode 95 Loss tf.Tensor(1.0907204, shape=(), dtype=float32)
# episode 95 Loss_frequency tf.Tensor(4.0769854, shape=(), dtype=float32)
# episode 95 Loss_action tf.Tensor(6.830219, shape=(), dtype=float32)
# One Episode Ended
# episode 96 Loss tf.Tensor(1.0837512, shape=(), dtype=float32)
# episode 96 Loss_frequency tf.Tensor(4.0114703, shape=(), dtype=float32)
# episode 96 Loss_action tf.Tensor(6.826042, shape=(), dtype=float32)
# One Episode Ended
# episode 97 Loss tf.Tensor(1.079747, shape=(), dtype=float32)
# episode 97 Loss_frequency tf.Tensor(4.0927353, shape=(), dtype=float32)
# episode 97 Loss_action tf.Tensor(6.7047343, shape=(), dtype=float32)
# One Episode Ended
# episode 98 Loss tf.Tensor(1.0886849, shape=(), dtype=float32)
# episode 98 Loss_frequency tf.Tensor(4.138448, shape=(), dtype=float32)
# episode 98 Loss_action tf.Tensor(6.7484007, shape=(), dtype=float32)
# One Episode Ended
# episode 99 Loss tf.Tensor(1.0694895, shape=(), dtype=float32)
# episode 99 Loss_frequency tf.Tensor(4.07281, shape=(), dtype=float32)
# episode 99 Loss_action tf.Tensor(6.622085, shape=(), dtype=float32)
# 29576.94974756241

# %%
plt.plot(Loss_record)
plt.xlabel('episoid')
plt.ylabel('Loss')
plt.grid()
plt.title('Accounted Training Loss')
file_name='loss_ours_saturation.mat'
savemat(file_name,{'Loss_record':Loss_record})

# %% [markdown]
# # Simulate

# %%
def Action(state,model,env):

    w_plus=K.dot(-tf.math.abs(model.variables[0]),cell.weight_recover).numpy()
    b_plus=K.dot(-tf.math.abs(model.variables[1]),cell.bias_recover).numpy()
    w_minus=K.dot(-tf.math.abs(model.variables[2]),cell.weight_recover).numpy()
    b_minus=K.dot(-tf.math.abs(model.variables[3]),cell.bias_recover).numpy()

    omega_th_max=omega_max*K.sigmoid(model.variables[4]).numpy()
    omega_th_min=omega_min*K.sigmoid(model.variables[5]).numpy()

    treshold_min_square=np.minimum(omega_th_max**(2),omega_th_min**(2))

    d=K.dot(model.variables[6],tf.eye(dim_omega,dtype=tf.float32))

    q_plus=(model.variables[7]).numpy()
    c_plus=(-tf.math.abs(model.variables[8])).numpy()
    q_minus=(model.variables[9]).numpy()
    c_minus=(-tf.math.abs(model.variables[10])).numpy()

    def getBinaryNumpy(imgNumpy, boundary = 0):
        one = np.ones_like(imgNumpy)
        zero = np.zeros_like(imgNumpy)
        return np.where(imgNumpy > boundary, one, zero)

    states_controlled = state@cell.select_omega

    status=getBinaryNumpy(states_controlled-omega_th_max)+getBinaryNumpy(omega_th_min-states_controlled)
    A_tilde=np.transpose(A_nom*np.squeeze(status))*np.squeeze(status)
    Laplacian_tilde_diag=np.sum(A_tilde,axis=0)
    Laplacian_tilde=-A_tilde+np.diag(Laplacian_tilde_diag)

    budgets_temp=d@Laplacian_tilde

    if np.max(-budgets_temp/treshold_min_square)<1:
      budgets=budgets_temp
    else:
      budgets=(budgets_temp/(np.max(-budgets_temp/(treshold_min_square))+1e-8))

    X_alpha_plus=-np.diag(np.squeeze(states_controlled-env.omega_max*np.ones((dim_omega,))))@cell.ones_frequency.numpy()+b_plus
    X_alpha_plus[X_alpha_plus<0]=0
    alpha_plus=np.sum(X_alpha_plus*w_plus,axis=1)
    X_alpha_minus=-np.diag(np.squeeze(env.omega_min*np.ones((cell.action_units,))-states_controlled))@cell.ones_frequency.numpy()+b_minus
    X_alpha_minus[X_alpha_minus<0]=0
    alpha_minus = np.sum(X_alpha_minus*w_minus,axis=1)

    q_xp = env.E*states_controlled+(np.sin(state@cell.select_lambda)@D_reactance)@D-np.squeeze(Pm)

    X_control_plus=np.diag(np.squeeze(states_controlled-omega_th_max))@cell.ones_frequency.numpy()+c_plus
    X_control_plus[X_control_plus<0]=0
    control_plus = np.sum(X_control_plus*q_plus,axis=1)
    X_control_minus=-np.diag(np.squeeze(states_controlled-omega_th_min))@cell.ones_frequency.numpy()+c_minus
    X_control_minus[X_control_minus<0]=0
    control_minus = K.sum(X_control_minus*q_minus,axis=1)
    control=control_plus+control_minus

    nonlinear_plus = getBinaryNumpy(states_controlled-omega_th_max, boundary=0)*\
                        np.minimum(np.minimum(states_controlled+budgets*((states_controlled+1e-8)**(-1)), -alpha_plus*((states_controlled-omega_th_max+1e-8)**(-1))+q_xp), control)
    nonlinear_minus = getBinaryNumpy(omega_th_min-states_controlled, boundary=0)*\
                        np.maximum(np.maximum(states_controlled+budgets*((states_controlled+1e-8)**(-1)), alpha_minus*((omega_th_min-states_controlled+1e-8)**(-1))+q_xp), control)
    #
    action = nonlinear_plus + nonlinear_minus

    # action = tf.math.minimum(tf.math.maximum(-3*tf.ones((1,dim_omega)),action),3*tf.ones((1,dim_omega))) ### projection

    return action

# %%
# Compare the trajectory

Trajectory_RNN_omega=[]
Trajectory_RNN_omega_true=[]
Trajectory_RNN_lambda=[]

init_state=equilibrium_init + s_concate

# init_state=env.reset()
s=init_state
s_record_all_omega = s@env.select_omega
s_record_all_omega_true = s_record_all_omega + 60*np.ones((1,dim_omega))
s_record_all_lambda = s@env.select_lambda
env.set_state(s)
Trajectory_RNN_omega.append(s_record_all_omega)
Trajectory_RNN_omega_true.append(s_record_all_omega_true)
Trajectory_RNN_lambda.append(s_record_all_lambda)
Test_time=50
SimulationLength=int(Test_time/delta_t)
Record_u=[]
Record_Loss=[]
Loss_RNN=0
Loss_RNN_discounted=0

generator_loss_node = 38
generator_loss_start_time = 0
generator_loss_period = 2
for i in range(SimulationLength):
    if i>=generator_loss_start_time/delta_t and i<=(generator_loss_start_time+generator_loss_period)/delta_t:
      Pm[0,generator_loss_node-1] = 0
    else:
      Pm[0,generator_loss_node-1] = Pm_nominal[0,generator_loss_node-1]
    u=Action(s,layer,env)
    next_s, r= env.step(u,Pm)
    Loss_RNN_discounted+=r
    Loss_RNN+=r
    s=next_s
    s_record_all_omega = s@env.select_omega
    s_record_all_omega_true = s_record_all_omega + 60*np.ones((1,dim_omega))
    s_record_all_lambda = s@env.select_lambda
    Trajectory_RNN_omega.append(s_record_all_omega)
    Trajectory_RNN_omega_true.append(s_record_all_omega_true)
    Trajectory_RNN_lambda.append(s_record_all_lambda)
    Record_u.append(u)
    Record_Loss.append(np.squeeze(r))
Trajectory_RNN_omega=np.squeeze(np.asarray(Trajectory_RNN_omega))
Trajectory_RNN_omega_true=np.squeeze(np.asarray(Trajectory_RNN_omega_true))
Trajectory_RNN_lambda=np.squeeze(np.asarray(Trajectory_RNN_lambda))
Record_u=np.squeeze(np.asarray(Record_u))
plt.figure(figsize=(18, 4), dpi=100)
TimeRecord=np.arange(1,SimulationLength+1)
TimeRecord=env.delta_t*TimeRecord
plt.subplot(1,3,1)

plt.plot(TimeRecord,Record_u)
plt.xlabel('Time (s)', fontsize=14)
plt.ylabel('Control action (p.u.)', fontsize=14)
plt.grid()

plt.subplot(1,3,2)

TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=env.delta_t*TimeRecord

plt.plot(TimeRecord,Trajectory_RNN_omega_true)
plt.xlabel('Time (s)', fontsize=14)
plt.ylabel('$\omega$ (rad/s)', fontsize=14)
plt.grid()

plt.subplot(1,3,3)

TimeRecord=np.arange(1,SimulationLength+2)
TimeRecord=env.delta_t*TimeRecord

plt.plot(TimeRecord,Trajectory_RNN_lambda)
plt.xlabel('Time (s)', fontsize=14)
plt.ylabel('$\lambda$ (rad)', fontsize=14)
plt.grid()

# %%
(np.sum(np.power(Record_u,2))+env.Penalty_action*np.sum(np.power(Trajectory_RNN_omega,2)))/(50/0.0008)

# %%
from scipy.io import loadmat
from scipy.io import savemat

w_plus=K.dot(-tf.math.abs(model.variables[0]),cell.weight_recover).numpy()
b_plus=K.dot(-tf.math.abs(model.variables[1]),cell.bias_recover).numpy()
w_minus=K.dot(-tf.math.abs(model.variables[2]),cell.weight_recover).numpy()
b_minus=K.dot(-tf.math.abs(model.variables[3]),cell.bias_recover).numpy()

omega_th_max=(omega_max*K.sigmoid(model.variables[4])).numpy()
omega_th_min=(omega_min*K.sigmoid(model.variables[5])).numpy()

d=(K.dot(model.variables[6],tf.eye(dim_omega,dtype=tf.float32))).numpy()

q_plus=(model.variables[7]).numpy()
c_plus=(-tf.math.abs(model.variables[8])).numpy()
q_minus=(model.variables[9]).numpy()
c_minus=(-tf.math.abs(model.variables[10])).numpy()

file_name='optimal_controllers_budgets.mat'
savemat(file_name,{'w_plus':w_plus,'w_minus':w_minus,'b_plus':b_plus,'b_minus':b_minus,'omega_th_max':omega_th_max,'omega_th_min':omega_th_min,'q_plus':q_plus,'q_minus':q_minus,'c_plus':c_plus,'c_minus':c_minus,'d':d})
